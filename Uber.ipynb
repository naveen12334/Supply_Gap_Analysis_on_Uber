# %%
import pandas as pd


import matplotlib.pyplot as plt
df = pd.read_csv("uberdata.csv",parse_dates=["request"], index_col="request")
#df = pd.read_csv("uberdata.csv", parse_dates=[0],date_parser=lambda x: pd.to_datetime(x, format='%m/%d/%Y %I:%M:%S %p'))


#df['request'] = df['request'].dt.strftime('%d/%m/%Y')

a1=df['2016-07-13  04:00':'2016-07-13 08:00']  #early morning
a2=df['2016-07-14  04:00':'2016-07-14 08:00']
a3=df['2016-07-15  04:00':'2016-07-15 08:00']

b1=df['2016-07-13  08:00':'2016-07-13 12:00']  #morning
b2=df['2016-07-14  08:00':'2016-07-14 12:00']  #morning
b3=df['2016-07-15  08:00':'2016-07-15 12:00']  #morning

c1=df['2016-07-13  12:00':'2016-07-13 16:00']#afternoon
c2=df['2016-07-14  12:00':'2016-07-14 16:00']#afternoon
c3=df['2016-07-15  12:00':'2016-07-15 16:00']#afternoon

d1=df['2016-07-13  16:00':'2016-07-13 20:00']#evening
d2=df['2016-07-14  16:00':'2016-07-14 20:00']#evening
d3=df['2016-07-15  16:00':'2016-07-15 20:00']#evening



e1=df['2016-07-13  20:00':'2016-07-13 23:59']#night
e2=df['2016-07-14  20:00':'2016-07-14 23:59']#night
e3=df['2016-07-15  20:00':'2016-07-15 23:59']#night


f1=df['2016-07-13  00:00':'2016-07-13 04:00']#late night
f2=df['2016-07-14  00:00':'2016-07-14 04:00']#late night
f3=df['2016-07-15  00:00':'2016-07-15 04:00']#late night


aa=[a1,a2,a3]
a=pd.concat(aa)
print(a)
bb=[b1,b2,b3]
b=pd.concat(bb)
cc=[c1,c2,c3]
c=pd.concat(cc)
dd=[d1,d2,d3]
d=pd.concat(dd)
ee=[e1,e2,e3]
e=pd.concat(ee)
ff=[f1,f2,f3]
f=pd.concat(ff)



r1=a["Status"].value_counts()
r2=b["Status"].value_counts()
r3=c["Status"].value_counts()
r4=d["Status"].value_counts()
r5=e["Status"].value_counts()
r5=f["Status"].value_counts()
plt.figure(1)
#a.to_csv("a.csv")
#x=a["Status"].value_counts().plot(kind='bar')
plt.subplot(131)
y=a["Status"].value_counts().plot(kind='bar')
plt.title("early morning")
plt.subplot(132)
x=b["Status"].value_counts().plot(kind='bar')
plt.title("morning")
plt.subplot(133)
x=c["Status"].value_counts().plot(kind='bar')
plt.title("afternoon")
plt.figure(2)
plt.subplot(131)
x=d["Status"].value_counts().plot(kind='bar')
plt.title("evening")
plt.subplot(132)
x=e["Status"].value_counts().plot(kind='bar')
plt.title("night")
plt.subplot(133)
x=f["Status"].value_counts().plot(kind='bar')
plt.title("late night")
plt.figure(3)
plt.subplot(131)
y=a["Pickup point"].value_counts().plot(kind='bar')
plt.title("early morning")
plt.subplot(132)
x=b["Pickup point"].value_counts().plot(kind='bar')
plt.title("morning")
plt.subplot(133)
x=c["Pickup point"].value_counts().plot(kind='bar')
plt.title("afternoon")
plt.figure(4)
plt.subplot(131)
x=d["Pickup point"].value_counts().plot(kind='bar')
plt.title("evening")
plt.subplot(132)
x=e["Pickup point"].value_counts().plot(kind='bar')
plt.title("night")
plt.subplot(133)
x=f["Pickup point"].value_counts().plot(kind='bar')
plt.title("late night")
plt.figure(5)
y=df["Pickup point"].value_counts().plot(kind='bar')
plt.title("city vs airport")

plt.figure(6)
plt.subplot(121)
y=a["Pickup point"].value_counts().plot(kind='bar')
plt.title("early morning")
plt.subplot(122)
y=a["Status"].value_counts().plot(kind='bar')
plt.title("early morning")
plt.figure(7)
plt.subplot(221)
x=d["Pickup point"].value_counts().plot(kind='bar')
plt.title("evening")
plt.subplot(222)
x=d["Status"].value_counts().plot(kind='bar')
plt.title("evening")
plt.subplot(223)
x=e["Pickup point"].value_counts().plot(kind='bar')
plt.title("night")
plt.subplot(224)
x=e["Status"].value_counts().plot(kind='bar')
plt.title("night")

plt.show()



 #morning
#y=e["Status"].value_counts().plot(kind='bar')
#plt.show(y)
#print(df['2016-07-13  12:00':'2016-07-13 4:00'])    #noon
#print(df['2016-07-13  4:00':'2016-07-13 8:00'])
#print(df['2016-07-13  8:00':'2016-07-13 12:00'])
#print(df['2016-07-13  12:00':'2016-07-13 4:00'])




#print(a["Sample"])
#print(df['Sample'].resample('H'))
#df['2016-07']


#b=a['Sample'].plot#plt.show(b)
#plt.figure(2)

#a=df['Close'].resample('M').mean().plot(kind='bar')
#plt.show(a)
# Out:
#                      Request id Pickup point  Driver id             Status  \
# request
# 2016-07-13 04:49:20        2784      Airport        2.0     Trip Completed
# 2016-07-13 05:34:20        2847      Airport        4.0     Trip Completed
# 2016-07-13 07:28:14        3014         City        5.0     Trip Completed
# 2016-07-13 06:50:33        2960      Airport        6.0     Trip Completed
# 2016-07-13 05:05:16        2808         City       16.0     Trip Completed
# ...                         ...          ...        ...                ...
# 2016-07-15 07:50:44        5739         City        NaN  No Cars Available
# 2016-07-15 07:55:54        5744         City        NaN  No Cars Available
# 2016-07-15 07:58:18        5745         City        NaN  No Cars Available
# 2016-07-15 07:58:52        5747         City        NaN  No Cars Available
# 2016-07-15 07:59:34        5743         City        NaN  No Cars Available
#
#                                    drop
# request
# ...
